# %% [markdown]
# # Topics to be covered : Strings, Array, File Handling
# Exercise based on above Topics:
#
# 1. Write a program to count the numbers of characters in the string and store
# them in a dictionary data structure
#
# 2. Write a program to use split and join methods in the string and trace a
# birthday of a person with a dictionary data structure
#
# 3. Write a program to count frequency of characters in a given file. Can you
# use character frequency to tell whether the given file is a Python program
# file, C program file or a text file?
#
# 4. Write a program to print each line of a file in reverse order.
#
# 5. Write a program to compute the number of characters, words and lines in a
# file.
#
# 6. Write a function nearly equal to test whether two strings are nearly equal.
# Two strings a and b are nearly equal when a can be generated by a single
# mutation on.
#
# 7. Write a program to implement Insertion sort.
#
# 8. Write a program to implement Selection sort

# %%
# Given String  
str = "ishu kumar"  
# Start Oth index to end  
print(str[0:])  
# Starts 1th index to 4th index  
print(str[1:5])  
# Starts 2nd index to 3rd index  
print(str[2:4])  
# Starts 0th to 2nd index  
print(str[:3])  
#Starts 4th to 6th index  
print(str[4:7])
# Out:
# ishu kumar
# shu
# hu
# ish
#  ku

# %%
str = "HELLO"    
print(str)    
str = "hello"    
print(str)
# Out:
# HELLO
# hello

# %%
str = "HELLO"    
str[0] == "h"    
print(str)
# Out:
# HELLO

# %%
a = "HellO, World!"
print(a.upper())
a = "HellO, World!"
print(a.lower())
# Out:
# HELLO, WORLD!
# hello, world!

# %%
#The strip() method removes any whitespace from the beginning or the end:

a = " Hello, World! "
print(a.strip()) # returns "Hello, World!"
# Out:
# Hello, World!

# %%
a="ishu kumar"
print(a.replace("u", "J"))
# Out:
# ishJ kJmar

# %%
#The split() method splits the string into substrings if it finds instances of the separator:

a = "Hello, World ,!"
print(a.split(",")) # returns ['Hello', ' World!']
# Out:
# ['Hello', ' World ', '!']

# %%
#Merge variable a with variable b into variable c:

a = "ishu"
b = "kumar"
c = a + b
print(c)
#To add a space between them, add a " ":

c = a + " " + b
print(c)
# Out:
# ishukumar
# ishu kumar

# %%
age = 36
txt = "My name is John, and I am {}"
print(txt.format(age))
# Out:
# My name is John, and I am 36

# %%
age = 36
txt = "My name is John, and I am {}".format(age)
print(txt)
# Out:
# My name is John, and I am 36

# %%
quantity = 3
itemno = 567
price = 49.95
myorder = "I want {} pieces of item {} for {} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item 567 for 49.95 dollars.

# %%
Integer = 10;    
Float = 1.290    
String = "Devansh"    
print("Hi I am Integer ... My value is %d\n Hi I am float ... My value is %f\n Hi I am string ... My value is %s" %(Integer,Float,String))
# Out:
# Hi I am Integer ... My value is 10
#  Hi I am float ... My value is 1.290000
#  Hi I am string ... My value is Devansh

# %% [markdown]
# # escape character

# %%
#The escape character allows you to use double quotes when you normally would not be allowed:
txt = "We are the so-called \"Vikings\" from the north."
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %%
# using triple quotes  
print('''"They said, "What's there?"''')  
  
# escaping single quotes  
print('They said, "What\'s going on?"')  
  
# escaping double quotes  
print("They said, \"What's going on?\"")
# Out:
# "They said, "What's there?"
# They said, "What's going on?"
# They said, "What's going on?"

# %%
#It ignores the new line.	
print("Python1 \
Python2 \
Python3")
# Out:
# Python1 Python2 Python3

# %%
print("C:\\Users\\DEVANSH SHARMA\\Python32\\Lib")  
print("This is the \n multiline quotes")  
print("This is \x48\x45\x05 representation")
# Out:
# C:\Users\DEVANSH SHARMA\Python32\Lib
# This is the
#  multiline quotes
# This is HE representation

# %% [markdown]
# # program1

# %% [markdown]
# 1. Write a program to count the numbers of characters in the string and store them in a dictionary data structure

# %%
str =input("enter the string")

f={}

for i in str:
    if i in f:
        f[i] += 1
        
    else:
        f[i]=1
print(f)
# Out:
# enter the stringishu
# {'i': 1, 's': 1, 'h': 1, 'u': 1}

# %% [markdown]
# 2. Write a program to use split and join methods in the string and trace a birthday of a person with a dictionary data structure

# %%
str =input("enter dob")
print(str)

#The split() method splits the string into substrings if it finds instances of the separator:


a=str.split("/")
print(a)

bday='-'.join(a)
print(bday)

req= input("enter bday to match")

if str == req:

  print("yes,Birthday date matched")

else:

  print("no,Birthday date not matched")
# Out:
# enter dob12/11/11
# 12/11/11
# ['12', '11', '11']
# 12-11-11
# enter bday to match12-11-11
# no,Birthday date not matched

# %%
# We can access the array elements using the respective indices of those elements.
from array import*  
a = array('i', [2, 4, 6, 8])  
print("First element:", a[0])  
print("Second element:", a[1])  
print("Second last element:", a[-1])
# Out:
# First element: 2
# Second element: 4
# Second last element: 8

# %%
import array as arr  
number = array('i', [1, 2, 3, 3, 4])  
del number[2]                           # removing third element  
print(number)

# %%
import array as arr  
number = arr.array('i', [1, 2, 3, 7, 4])  
x=len(number)                           
print(x)

# %%
import array as arr 
a=arr.array('d',[1.1 , 2.1 ,3.1,2.6,7.8])  
b=arr.array('d',[3.7,8.6])  
c=arr.array('d')  
c=a+b  
print("Array c = ",c)
# Out:
# Array c =  array('d', [1.1, 2.1, 3.1, 2.6, 7.8, 3.7, 8.6])

# %% [markdown]
# # 7 Insertion program

# %%
a = [16, 19, 11, 15, 10, 12, 14]

#iterating over a
for i in a:
    j = a.index(i)
    #i is not the first element
    while j>0:
        #not in order
        if a[j-1] > a[j]:
            #swap
            a[j-1],a[j] = a[j],a[j-1]
        else:
            #in order
            break
        j = j-1
print (a)

# %% [markdown]
# # 8 Selection sort

# %%
a = [16, 19, 11, 15, 10, 12, 14]

i = 0
while i<len(a):
    #smallest element in the sublist
    smallest = min(a[i:])
    #index of smallest element
    index_of_smallest = a.index(smallest)
    #swapping
    a[i],a[index_of_smallest] = a[index_of_smallest],a[i]
    i=i+1
print (a)

# %% [markdown]
# # 3

# %%
#opens the file file.txt in read mode    
fileptr = open("C:\\Users\\ishuk\\Desktop\\sem 6\\lab\\python\\exp4\\test.txt","r")    
#fileptr1= open("//test.txt","r")

if fileptr:    
    print("file is opened successfully")
# Out:
# file is opened successfully

# %%
#Example
#Return the 5 first characters of the file:

f = open("C:\\Users\\ishuk\\Desktop\\sem 6\\lab\\python\\exp4\\test.txt","r")  
print(f.read(5))
# Out:
# my na

# %%
#Example
#Read one line of the file:
f = open("C:\\Users\\ishuk\\Desktop\\sem 6\\lab\\python\\exp4\\test.txt","r")  
print(f.readline())
#Example
#Read two lines of the file:

print(f.readline())
print(f.readline())
# Out:
# my name is ishu

# %%
#Example
#Loop through the file line by line:
f = open("C:\\Users\\ishuk\\Desktop\\sem 6\\lab\\python\\exp4\\test.txt","r")  
for x in f:
    print(x)
#Example
# Out:
# my name is ishu

# %%
#Example
#Close the file when you are finish with it:

f = open("C:\\Users\\ishuk\\Desktop\\sem 6\\lab\\python\\exp4\\test.txt","r")  
print(f.readline())
f.close()
# Out:
# my name is ishu

# %% [markdown]
# # 4

# %%
with open("C:\\Users\\ishuk\\Desktop\\sem 6\\lab\\python\\exp4\\test.txt", 'r') as f:
    lines = f.readlines()
    for line in lines:
        print(line.strip()[::-1])
# Out:
# uhsi si eman ym

# %% [markdown]
# # 5

# %%
# Python implementation to compute
# number of characters, words, spaces
# and lines in a file

# importing os module
import os

# Function to count number
# of characters, words, spaces
# and lines in a file
def counter(fname):
	
	# variable to store total word count
	num_words = 0
	
	# variable to store total line count
	num_lines = 0
	
	# variable to store total character count
	num_charc = 0
	
	# variable to store total space count
	num_spaces = 0
	
	# opening file using with() method
	# so that file gets closed
	# after completion of work
	with open(fname, 'r') as f:
		
		# loop to iterate file
		# line by line
		for line in f:
			
			# separating a line
			# from \n character
			# and storing again in line
			# variable for further operations
			line = line.strip(os.linesep)
			
			# splitting the line
			# to make a list of
			# all the words present
			# in that line and storing
			# that list in
			# wordlist variable
			wordslist = line.split()
			
			# incrementing value of
			# num_lines with each
			# iteration of loop to
			# store total line count
			num_lines = num_lines + 1
			
			# incrementing value of
			# num_words by the
			# number of items in the
			# list wordlist
			num_words = num_words + len(wordslist)
			
			# incrementing value of
			# num_charc by 1 whenever
			# value of variable c is other
			# than white space in the separated line
			num_charc = num_charc + sum(1 for c in line
						if c not in (os.linesep, ' '))
			
			# incrementing value of
			# num_spaces by 1 whenever
			# value of variable s is
			# white space in the separated line
			num_spaces = num_spaces + sum(1 for s in line
								if s in (os.linesep, ' '))
	
	# printing total word count
	print("Number of words in text file: ",
		num_words)
	
	# printing total line count
	print("Number of lines in text file: ",
		num_lines)
	
	# printing total character count
	print("Number of characters in text file: ",
		num_charc)
	
	# printing total space count
	print("Number of spaces in text file: ",
		num_spaces)

# Driver Code:
if __name__ == '__main__':
	fname = "C:\\Users\\ishuk\\Desktop\\sem 6\\lab\\python\\exp4\\test.txt"
	try:
		counter(fname)
	except:
		print('File not found')
# Out:
# Number of words in text file:  4
# Number of lines in text file:  1
# Number of characters in text file:  12
# Number of spaces in text file:  3

# %% [markdown]
# # 6

# %%
#write a function nearly _equal to test whether two strings are nearly equal. two strings a and b are nearly equal when a can be generated by a single mutation on b.


def nearly_equal(str1,str2):
  count=0
  i=j=0
  while(i<len(str1) and j<len(str2)):
    if(str1[i]!=str2[j]):
      count=count+1

      if(len(str1)>len(str2)):
        i=i+1

      elif(len(str1)==len(str2)):
          pass
      else:
          i=i-1
  
    if(count>1):
      return False
    i=i+1
    j=j+1
  if(count<2):
      return True
      
str1=input("enter first string::\n" )
str2=input("enter second string::\n")
boolean=nearly_equal(str1,str2)
if(boolean):
  print("strings are nearly equal.")
else:
  print("strings are not equal.")
# Out:
# enter first string::
# ishukujk
# enter second string::
# ish
# strings are nearly equal.
